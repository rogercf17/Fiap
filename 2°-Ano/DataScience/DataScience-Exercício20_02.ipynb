# %% [markdown]
# # Data Science - Aula 1 Exercícios

# %% [markdown]
# ### Integrantes:
# * Gabriel Machado Lacerda - RM 556714
# * Luan Orlandelli Ramos - RM 554747
# * Roger Cardoso Ferreira - RM 557230

# %%
import pandas as pd

# %%
df_lista = pd.read_csv('/content/lista.csv')
df_lista
# Out:
#            Base de Dados                                          Exercício
# 0   Heróis (Marvel & DC)       1️⃣ Liste todos os heróis da editora Marvel.
# 1   Heróis (Marvel & DC)           2️⃣ Qual é o herói mais antigo da lista?
# 2   Heróis (Marvel & DC)      3️⃣ Qual é a média de força dos heróis da DC?
# 3   Heróis (Marvel & DC)  4️⃣ Qual editora tem a maior média de inteligê...
# 4   Heróis (Marvel & DC)                     5️⃣ Qual é o herói mais veloz?
# 5   Heróis (Marvel & DC)        6️⃣ Quantos heróis estrearam antes de 1960?
# 6   Heróis (Marvel & DC)  7️⃣ Qual é a soma total da força dos heróis da...
# 7   Heróis (Marvel & DC)  8️⃣ Liste os heróis em ordem decrescente de ve...
# 8   Heróis (Marvel & DC)    9️⃣ Qual é a média de estreia dos heróis da DC?
# 9   Heróis (Marvel & DC)     🔟 Qual o nome do herói mais forte entre todos?
# 10           Corinthians              1️⃣ Qual foi o ano com mais vitórias?
# ...

# %%
df = pd.read_csv('/content/marvel dc.csv')
df
# Out:
#                Nome Editora  Ano_Estreia  Força  Inteligência  Velocidade
# 0            Batman      DC         1939     85           100          80
# 1          Superman      DC         1938    100            90         100
# 2  Mulher-Maravilha      DC         1941     95            92          85
# 3    Homem de Ferro  Marvel         1963     90           100          88
# 4   Capitão América  Marvel         1941     92            85          84
# 5              Hulk  Marvel         1962    100            80          75
# 6             Flash      DC         1956     88            88         100
# 7              Thor  Marvel         1962    100            90          90
# 8           Aquaman      DC         1941     86            82          85
# 9      Homem-Aranha  Marvel         1962     89            85          95

# %%
# Exercício 1 - Liste todos os heróis da editora Marvel.
df[df['Editora'] == 'Marvel']
# Out:
#               Nome Editora  Ano_Estreia  Força  Inteligência  Velocidade
# 3   Homem de Ferro  Marvel         1963     90           100          88
# 4  Capitão América  Marvel         1941     92            85          84
# 5             Hulk  Marvel         1962    100            80          75
# 7             Thor  Marvel         1962    100            90          90
# 9     Homem-Aranha  Marvel         1962     89            85          95

# %%
# Exercício 2 - Qual é o herói mais antigo da lista?
data_mais_antiga = df['Ano_Estreia'].min()
df[df['Ano_Estreia'] == data_mais_antiga]
# Out:
#        Nome Editora  Ano_Estreia  Força  Inteligência  Velocidade
# 1  Superman      DC         1938    100            90         100

# %%
# Exercício 3 - Qual é a média de força dos heróis da DC?
media_de_forca = df['Força'].mean()
print(f'Média de força de todos os hérois é: {media_de_forca}')
# Out:
# Média de força de todos os hérois é: 92.5

# %%
# Exercício 4 - Qual editora tem a maior média de inteligência...
inteligencia = df.groupby('Editora')['Inteligência'].sum()
if inteligencia.DC > inteligencia.Marvel:
    print('DC é a editora com mais inteligência entre os herois')
else:
     print('Marvel é a editora com mais inteligência entre os herois')
# Out:
# DC é a editora com mais inteligência entre os herois

# %%
# Exrcício 5 - Qual é o herói mais veloz?
maior_velocidade = df['Velocidade'].max()
df[df['Velocidade'] == maior_velocidade]
# Out:
#        Nome Editora  Ano_Estreia  Força  Inteligência  Velocidade
# 1  Superman      DC         1938    100            90         100
# 6     Flash      DC         1956     88            88         100

# %%
# Exercício 6 - Quantos heróis estrearam antes de 1960?
herois_velhos = df[df['Ano_Estreia'] < 1960]

herois_velhos
# Out:
#                Nome Editora  Ano_Estreia  Força  Inteligência  Velocidade
# 0            Batman      DC         1939     85           100          80
# 1          Superman      DC         1938    100            90         100
# 2  Mulher-Maravilha      DC         1941     95            92          85
# 4   Capitão América  Marvel         1941     92            85          84
# 6             Flash      DC         1956     88            88         100
# 8           Aquaman      DC         1941     86            82          85

# %%
print(f'{herois_velhos.shape[0]} estrearam antes de 1960.')
# Out:
# 6 estrearam antes de 1960.

# %%
# Exercício 7 - Qual é a soma total da força dos heróis da Marvel
herois_marvel = df[df['Editora'] == 'Marvel']
forca_total = herois_marvel['Força'].sum()
print(f'A soma das forças dos hérois da marvel é igual a {forca_total}')
# Out:
# A soma das forças dos hérois da marvel é igual a 471

# %%
# Exercício 8 - Liste os heróis em ordem decrescente de velocidade
df.sort_values(by='Velocidade', ascending=False)
# Out:
#                Nome Editora  Ano_Estreia  Força  Inteligência  Velocidade
# 1          Superman      DC         1938    100            90         100
# 6             Flash      DC         1956     88            88         100
# 9      Homem-Aranha  Marvel         1962     89            85          95
# 7              Thor  Marvel         1962    100            90          90
# 3    Homem de Ferro  Marvel         1963     90           100          88
# 2  Mulher-Maravilha      DC         1941     95            92          85
# 8           Aquaman      DC         1941     86            82          85
# 4   Capitão América  Marvel         1941     92            85          84
# 0            Batman      DC         1939     85           100          80
# 5              Hulk  Marvel         1962    100            80          75

# %%
# Exercício 9 - Qual é a média de estreia dos heróis da DC?
herois_dc = df[df['Editora'] == 'DC']
int(herois_dc['Ano_Estreia'].mean())
# Out:
# 1943

# %%
# Exercício 10 - Qual o nome do herói mais forte entre todos?
maior_forca = df['Força'].max()
df[df['Força'] == maior_forca]
# Out:
#        Nome Editora  Ano_Estreia  Força  Inteligência  Velocidade
# 1  Superman      DC         1938    100            90         100
# 5      Hulk  Marvel         1962    100            80          75
# 7      Thor  Marvel         1962    100            90          90

# %%
df3 = pd.read_csv('/content/todo poderoso timão.csv')
df3
# Out:
#     Ano  Jogos  Vitórias  Empates  Derrotas  Gols_Marcados  Gols_Sofridos  \
# 0  2015     61        30       14        12             49             59
# 1  2016     42        27       10        11             85             29
# 2  2017     69        35        6         6             58             41
# 3  2018     47        27       11        14             30             29
# 4  2019     56        33       11        11             49             29
# 5  2020     45        32        8         6             72             49
# 6  2021     49        35       12         8             70             20
# 7  2022     40        36        7        10             70             34
# 8  2023     53        30       13        14             37             48
# 9  2024     64        22        6         5             89             48
#
#    Posição_Campeonato
# 0                  19
# 1                   4
# 2                  10
# 3                  17
# 4                   6
# ...

# %%
# Exercício 11
df3[df3["Vitórias"] == df3["Vitórias"].max()][["Ano", "Vitórias"]]
# Out:
#     Ano  Vitórias
# 7  2022        36

# %%
# Exercício 12
df3.rename(columns={"VitÃ³rias": "Vitorias", "Gols_Marcados": "GolsMarcados", "Gols_Sofridos": "GolsSofridos"}, inplace=True)
df3["SaldoGols"] = df3["GolsMarcados"] - df3["GolsSofridos"]
df3[["Ano", "SaldoGols"]]
# Out:
#     Ano  SaldoGols
# 0  2015        -10
# 1  2016         56
# 2  2017         17
# 3  2018          1
# 4  2019         20
# 5  2020         23
# 6  2021         50
# 7  2022         36
# 8  2023        -11
# 9  2024         41

# %%
# Exercício 13
df3['Posição_Campeonato'].mean()
# Out:
# 12.3

# %%
# Exercício 14
df3[df3['Gols_Marcados'] > 60][['Ano']]

# %%
# Exercício 15
df3['Taxa_Vitorias'] = (df3['Vitórias'] / df3['Jogos'] * 100).round(1)
df3[['Ano', 'Taxa_Vitorias']].sort_values(by='Ano')
# Out:
#     Ano  Taxa_Vitorias
# 0  2015           49.2
# 1  2016           64.3
# 2  2017           50.7
# 3  2018           57.4
# 4  2019           58.9
# 5  2020           71.1
# 6  2021           71.4
# 7  2022           90.0
# 8  2023           56.6
# 9  2024           34.4

# %%
# Exercício 16
df3['Pontos'] = (df3['Vitórias'] * 3) + df3['Empates']

# Ordenando por pontos em ordem decrescente
resultado = df3[['Ano', 'Vitórias', 'Empates', 'Pontos']].sort_values(by='Pontos', ascending=False)
print(resultado)
# Out:
#     Ano  Vitórias  Empates  Pontos
# 6  2021        35       12     117
# 7  2022        36        7     115
# 2  2017        35        6     111
# 4  2019        33       11     110
# 0  2015        30       14     104
# 5  2020        32        8     104
# 8  2023        30       13     103
# 3  2018        27       11      92
# 1  2016        27       10      91
# 9  2024        22        6      72

# %%
# Exercício 17
df3[df3['Posição_Campeonato'] == df3['Posição_Campeonato'].min()][['Ano']]
# Out:
#     Ano
# 5  2020

# %%
# Exercício 18
df3[df3['Jogos'] == df3['Jogos'].max()][['Ano']]
# Out:
#     Ano
# 2  2017

# %%
# Exercício 19
df3['Gols_Ano'] = df3['Gols_Sofridos'] / df3['Jogos']
df3[['Gols_Ano', 'Ano']]

# %%
df2 = pd.read_csv('/content/filmes.csv')
df2
# Out:
#                  Título   Ano  Bilheteria_Mundial  Nota_IMDb  Duração_Minutos  \
# 0     O Poderoso Chefão  1972                 287        9.2              175
# 1               Titanic  1997                2187        7.8              195
# 2          Interestelar  2014                 701        8.6              169
# 3                Matrix  1999                 466        8.7              136
# 4  Vingadores: Ultimato  2019                2798        8.4              181
# 5         Clube da Luta  1999                 101        8.8              139
# 6          Pulp Fiction  1994                 213        8.9              154
# 7    O Senhor dos Anéis  2001                2917        8.8              178
# 8               Coringa  2019                1074        8.4              122
# 9                  Duna  2021                 402        8.0              155
#
#               Gênero
# 0              Crime
# 1            Romance
# 2  Ficção Científica
# 3  Ficção Científica
# ...

# %%
#Exercício 20
df2[df2['Gênero'] == 'Ficção Científica']
# Out:
#          Título   Ano  Bilheteria_Mundial  Nota_IMDb  Duração_Minutos  \
# 2  Interestelar  2014                 701        8.6              169
# 3        Matrix  1999                 466        8.7              136
# 9          Duna  2021                 402        8.0              155
#
#               Gênero
# 2  Ficção Científica
# 3  Ficção Científica
# 9  Ficção Científica

# %%
#Exercício 21
mais_antigo = df2.sort_values(by='Ano', ascending=True)
mais_antigo.head(1)
# Out:
#               Título   Ano  Bilheteria_Mundial  Nota_IMDb  Duração_Minutos  \
# 0  O Poderoso Chefão  1972                 287        9.2              175
#
#   Gênero
# 0  Crime

# %%
#Exercício 22
df2['Bilheteria_Mundial'].mean()
# Out:
# 1114.6

# %%
#Exercício 23
maior_nota = df2.sort_values(by='Nota_IMDb', ascending=False)
maior_nota.head(1)
# Out:
#               Título   Ano  Bilheteria_Mundial  Nota_IMDb  Duração_Minutos  \
# 0  O Poderoso Chefão  1972                 287        9.2              175
#
#   Gênero
# 0  Crime

# %%
#Exercício 24
df2.sort_values(by='Duração_Minutos', ascending=False)
# Out:
#                  Título   Ano  Bilheteria_Mundial  Nota_IMDb  Duração_Minutos  \
# 1               Titanic  1997                2187        7.8              195
# 4  Vingadores: Ultimato  2019                2798        8.4              181
# 7    O Senhor dos Anéis  2001                2917        8.8              178
# 0     O Poderoso Chefão  1972                 287        9.2              175
# 2          Interestelar  2014                 701        8.6              169
# 9                  Duna  2021                 402        8.0              155
# 6          Pulp Fiction  1994                 213        8.9              154
# 5         Clube da Luta  1999                 101        8.8              139
# 3                Matrix  1999                 466        8.7              136
# 8               Coringa  2019                1074        8.4              122
#
#               Gênero
# 1            Romance
# 4               Ação
# 7           Fantasia
# 0              Crime
# ...

# %%
#Exercício 25
df2['Bilheteria_Mundial'].sum()
# Out:
# 11146

# %%
#Exercício 26
df2[df2['Duração_Minutos'] < 150]
# Out:
#           Título   Ano  Bilheteria_Mundial  Nota_IMDb  Duração_Minutos  \
# 3         Matrix  1999                 466        8.7              136
# 5  Clube da Luta  1999                 101        8.8              139
# 8        Coringa  2019                1074        8.4              122
#
#               Gênero
# 3  Ficção Científica
# 5              Drama
# 8              Drama

# %%
#Exercício 27
df2[df2['Ano'] > 2000]
# Out:
#                  Título   Ano  Bilheteria_Mundial  Nota_IMDb  Duração_Minutos  \
# 2          Interestelar  2014                 701        8.6              169
# 4  Vingadores: Ultimato  2019                2798        8.4              181
# 7    O Senhor dos Anéis  2001                2917        8.8              178
# 8               Coringa  2019                1074        8.4              122
# 9                  Duna  2021                 402        8.0              155
#
#               Gênero
# 2  Ficção Científica
# 4               Ação
# 7           Fantasia
# 8              Drama
# 9  Ficção Científica

# %%
#Exercício 28
df2['Duração_Minutos'].mean()
# Out:
# 160.4

# %%
#Exercício 29
maior_bilheteria = df2.sort_values(by='Bilheteria_Mundial', ascending=False)
maior_bilheteria.head(1)
# Out:
#                Título   Ano  Bilheteria_Mundial  Nota_IMDb  Duração_Minutos  \
# 7  O Senhor dos Anéis  2001                2917        8.8              178
#
#      Gênero
# 7  Fantasia
